# %%
# f strings

# %%
firstname= 'divya'
lastname='shetty'

# %%
fullname = f'{firstname} {lastname}'
print(fullname)
# Out:
# divya shetty

# %%
firstname= 'raj'
lastname='shetty'

# %%
fullname = f'{firstname} {lastname}'
print(fullname)
# Out:
# raj shetty

# %%
msg = f'my name is {fullname}'
print(msg)
# Out:
# my name is raj shetty

# %%
print("sub:maths,engilsh, kannada, hindi, chem, bio")
# Out:
# sub:maths,engilsh, kannada, hindi, chem, bio

# %%
print("sub:\nmaths,\nengilsh, \nkannada, \nhindi, \nchem, \nbio")
# Out:
# sub:
# maths,
# engilsh,
# kannada,
# hindi,
# chem,
# bio

# %%
print("sub:\t\nmaths,\nengilsh, \nkannada, \nhindi, \nchem, \nbio")
# Out:
# sub:
# maths,
# engilsh,
# kannada,
# hindi,
# chem,
# bio

# %%
print("sub:\n\tmaths,\n\tengilsh, \n\tkannada, \n\thindi, \n\tchem, \n\tbio")
# Out:
# sub:
# 	maths,
# 	engilsh,
# 	kannada,
# 	hindi,
# 	chem,
# 	bio

# %%
#White spaces

# %%
sub = '            python             '
print(sub)
# Out:
#             python

# %%
sub = '        python'
print(sub)
print(sub.lstrip())
# Out:
#         python
# python

# %%
sub = 'python     '
print(sub)
print(sub.rstrip())
# Out:
# python
# python
