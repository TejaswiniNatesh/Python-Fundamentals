# %% [raw]
# Variable is name that is used to store values and it acts as a placeholder

# %%
a= 10
b=20
print(a+b)
# Out:
# 30

# %%
#Rules for naming Variable :
#Rule 1: No spacing while delecaring the variables.
first name = "Raju"
print(first name)
# Out:
#   Cell In[2], line 3
#     first name = "Raju"
#           ^
# SyntaxError: invalid syntax

# %%
firstname='Raju'
print(firstname)
# Out:
# Raju

# %%
#Rule 2 : Should not start with numbers

# %%
1name='raj'
print(1name)
# Out:
#   Cell In[4], line 1
#     1name='raj'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1='raj'
print(name1)
# Out:
# raj

# %%
#rule 3 Name should not contain special characters (`,!,@,#,$,%,^,&,*)

# %%
@name= "Raja"
print(@name)
# Out:
#   Cell In[6], line 1
#     @name= "Raja"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name="ram"
name1='ram'
print(name)
print(name1)
# Out:
# ram
# ram

# %%
name = 'Shanta'
print(type(name))
# Out:
# <class 'str'>

# %%
#Formatting the sentences or word

# %%
name= 'tejaswini natesh'

# %%
print(name.title())
# Out:
# Tejaswini Natesh

# %%
print(name.upper())
# Out:
# TEJASWINI NATESH

# %%
print(name.upper())
