# %%
# LIST

# %%
names= ["ram", "sham", "raju", "divya" , "swathi"]

# %%
print(names)
# Out:
# ['ram', 'sham', 'raju', 'divya', 'swathi']

# %%
print(type(names))
# Out:
# <class 'list'>

# %%
#Indexing

# %%
students=['akhila','dinesh','azlan','david']
print(students[1])
# Out:
# dinesh

# %%
print(students[3])
# Out:
# david

# %%
# adding new elements

# %%
names.append('raj')
print(names)
# Out:
# ['ram', 'sham', 'raju', 'divya', 'swathi', 'raj']

# %%
names.append('pallavi')

# %%
print(names)
# Out:
# ['ram', 'sham', 'raju', 'divya', 'swathi', 'raj', 'pallavi']

# %%
names.insert(3,"sindhu")
print(names)
# Out:
# ['ram', 'sham', 'raju', 'sindhu', 'divya', 'swathi', 'raj', 'pallavi']

# %%
names.insert(1,"shilpa")
print(names)
# Out:
# ['ram', 'shilpa', 'sham', 'raju', 'sindhu', 'divya', 'swathi', 'raj', 'pallavi']

# %%
del names[5]

# %%
print(names)
# Out:
# ['ram', 'shilpa', 'sham', 'raju', 'sindhu', 'swathi', 'raj', 'pallavi']

# %%
del names[3]

# %%
print(names)
# Out:
# ['ram', 'shilpa', 'sham', 'sindhu', 'swathi', 'raj', 'pallavi']
